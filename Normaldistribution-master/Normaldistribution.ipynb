# %%
import random
import matplotlib.pyplot as plt

left = 0##钉板的左边界
right = 100##钉板的右边界
ball=10000##小球的总数量
nail_floor = 100##钉板的钉子层数

def get_mouth():
    return 50

def dropin(n):
    position = n+ random.choice([-1,1])
    if position<left:
        return left
    elif position >right:
        return right
    else:
        return position
    
a = [0] * nail_floor
for i in range(0,ball):
    p =get_mouth()
    for n in range(0,nail_floor):
        p=dropin(p)
    a[p]+=1
a = list(filter((0).__ne__, a))
print(a)
print("长度：",len(a))
plt.plot(list(range(0,len(a))),a)
plt.show()
# Out:
# [1, 1, 3, 4, 9, 15, 28, 43, 76, 96, 162, 221, 273, 382, 435, 578, 701, 692, 836, 770, 801, 751, 653, 578, 506, 396, 335, 220, 153, 99, 80, 42, 31, 11, 12, 2, 4]
# 长度： 37

# %%
# !git push origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git
